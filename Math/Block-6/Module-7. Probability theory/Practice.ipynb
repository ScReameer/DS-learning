# %% [markdown]
# # <center>Условная вероятность
# **Задание 3.4**
# Среди людей, заходящих в магазин, 70 % ничего не покупают. Остальные с равной вероятностью покупают одну-три бутылки воды. Найдите вероятность купить две бутылки воды, если известно, что количество купленных бутылок чётное.
# $$ P(\{2\} | \{0, 2\}) = \frac{P(\{2\} \cap P(\{0,2\}))}{P(\{2\})} $$

# %%
round((0.1) / (0.7 + 0.1), 3)
# Out:
# 0.125

# %% [markdown]
# **Задание 3.5**
# Аналитик, работающий в спортивном клубе, проанализировал данные и нашёл следующие вероятности:
# * $ P(\text{клиент начал заниматься в январе} = 0.12) $
# * $ P(\text{клиент занимается в зале более 6 месяцев} = 0.5) $
# * $ P(\text{клиент занимается в зале более 6 месяцев и начал заниматься в январе} = 0.024) $
#
# Найдите вероятность того, что клиент занимается в клубе более шести месяцев, если известно, что он купил абонемент в январе и сразу же приступил к занятиям.
#
# $ P(\text{занимается более 6 месяцев} | \text{клиент начал заниматься в январе}) = \frac{P(\text{занимается более 6 месяцев} \cap \text{начал заниматься в январе})}{P(\text{начал заниматься в январе})} = \frac{0.024}{0.12} $

# %%
0.024 / 0.12
# Out:
# 0.2

# %% [markdown]
# **Задание 3.6**
# Владелец салона красоты решил подсчитать, какими услугами пользовались его клиенты на прошлой неделе. Получились следующие результаты:
#
# ![image.png](attachment:image.png)
#
# Найдите вероятность того, что случайный клиент захочет сделать стрижку в салоне, если он уже записался на макияж.
#
# $$ P(стрижка|макияж) = \frac{P(стрижка \cap макияж)}{P(макияж)} = \frac{10\%}{5\% + 10\%} = \frac{0.1}{0.15} $$

# %%
round(0.1 / 0.15, 2)
# Out:
# 0.67

# %% [markdown]
# **Задание 4.3**
# Вы едете на деловую встречу в бизнес-центр. Когда на дорогах нет пробок, вероятность не опоздать к назначенному времени составляет для вас 0.9, а когда на улицах пробки, то вероятность успеть вовремя уменьшается до 0.7. Известно, что в том районе, где находится бизнес-центр, пробки бывают в 60 % случаев.
#
# С какой вероятностью вы успеете приехать на деловую встречу без опозданий?
#
# * $ P(TJ) = 0.6 $ - вероятность **наличия пробки**
# * $ P(nTJ) = 0.4 $ - вероятность **отсутствия пробки**
# * $ P(nL|nTJ) = 0.9 $ - вероятность **не опоздать**, когда **нет пробок**
# * $ P(L|nTJ) = 0.1 $ - вероятность **опоздать**, когда **нет пробок**
# * $ P(nL|TJ) = 0.7 $ - вероятность **не опоздать**, когда **есть пробки**
# * $ P(L|TJ) = 0.3 $ - вероятность **опоздать**, когда **есть пробки**
#
# $$ P(nL) = P(nL|nTJ) \cdot P(nTJ) + P(nL|TJ) \cdot P(TJ) = 0.9 \cdot 0.4 + 0.7 \cdot 0.6 = 0.78 $$
#
# **Задание 4.4**
# В одном из отделов банка работает 80 % сотрудников с опытом и 20 % новичков. Вероятность, что опытный сотрудник совершит ошибку при проведении банковской операции, равна 0.01. Вероятность, что такую же ошибку совершит новичок, в 50 раз больше.
#
# Найдите вероятность того, что случайная банковская операция будет произведена без ошибок.
#
# * $ P(E) = 0.8 $ - сотрудники **с опытом**
# * $ P(nE) = 0.2 $ - сотрудники **без опыта**
# * $ P(F|E) = 0.01 $ - вероятность, что **опытный** сотрудник **совершит ошибку**
# * $ P(nF|E) = 0.99 $ - вероятность, что **опытный** сотрудник **не совершит ошибку**
# * $ P(F|nE) = 0.5 $ - вероятность, что **неопытный** сотрудник **совершит ошибку**
# * $ P(nF|nE) = 0.5 $ - вероятность, что **неопытный** сотрудник **не совершит ошибку**
#
# $$ P(nF) = P(nF|E) \cdot P(E) + P(nF|nE) \cdot P(nE) = 0.99 \cdot 0.8 + 0.5 \cdot 0.2 = 0.892 $$
#
# **Задание 4.5**
# Вы выяснили, что 2 % клиентов испытали wow-эффект от вашего сервиса и рассказывают о вас буквально всем — из них 70 % приведут новых клиентов. Ещё 20 % клиентов периодически оставляют вам положительные отзывы в соцсетях и на сайте — из них 10 % приведут новых клиентов. Что думают оставшиеся 78 % клиентов, вы не знаете — из них 4 % приведут новых клиентов.
# * $ P(W) = 0.02 $ - клиенты, **испытавшие wow-эффект**
# * $ P(N) = 0.2 $ - клиенты, **оставившие положительные отзывы**
# * $ P(O) = 0.78 $ - клиенты, о которых **нет информации**
# * $ P(C|W) = 0.7 $ - клиенты, которые **испытали wow-эффект** и **привели новых клиентов**
# * $ P(C|N) = 0.1 $ - клиенты, которые **оставили положительные отзывы** и **привели новых клиентов**
# * $ P(C|O) = 0.04 $ - клиенты, о которых **нет информации** и **привели новых клиентов**
#
# $ P(C) = P(C|W) \cdot P(W) + P(C|N) \cdot P(N) + P(C|O) \cdot P(O) = 0.7 \cdot 0.02 + 0.1 \cdot 0.2 + 0.04 \cdot 0.78 = 0.0652 $ - вероятность, что **случайный** клиент сервиса приведёт **нового клиента**.
#
# $ P(O|C) = \frac{P(C \cap O)}{P(C)} = \frac{P(C|O) \times P(O)}{P(C)} = \frac{0.04 \times 0.78}{0.0652} \approx 0.48 $ - вероятность, что клиент, о котором **нет информации**, привёл **нового клиента**
# 1. Вычислите апостериорную вероятность принадлежности клиента к классу «wow-эффект», если известно, что он привёл нового клиента.
#
#     $ P(W|C) = \frac{P(C|W) \times P(W)}{P(C)} = \frac{0.7 \times 0.02}{0.0652} \approx 0.21 $
# 2. Вычислите апостериорную вероятность принадлежности клиента к классу «тихоня», если известно, что он привёл нового клиента.
#
#     $ P(O|C) = \frac{P(C|O) \times P(O)}{P(C)} = \frac{0.04 \times 0.78}{0.0652} \approx 0.48 $
# 3. Вычислите апостериорную вероятность принадлежности клиента к классу «тихоня», если известно, что он **не** привёл нового клиента.
#
#     $ P(\overline{C}) = 1 - P(C) = 0.9348 $
#     $ P(\overline{C}|O) = 1 - P(C|O) = 0.96 $
#     $ P(O|\overline{C}) = \frac{P(\overline{C}|O) \times P(O)}{P(\overline{C})} = \frac{0.96 \times 0.78}{0.9348} \approx 0.8 $
#
# **Задание 5.4**
# В компании решили отправить сотрудников на обучение по трём корпоративным программам. Было решено, что 20 % сотрудников будут обучаться программированию, 35 % — ораторскому мастерству, и 45 % — повышать свой уровень владения иностранным языком. Известно, что по статистике 80 % сотрудников, которые учатся программированию, впоследствие успешно сдают зачётный экзамен. Для курсов по ораторскому мастерству такой процент равен 75 %, а для обучения иностранным языкам — 60%.
#
# * $ P(P) = 0.2 $ - обучение **программированию**
# * $ P(O) = 0.35 $ - обучение **ораторскому мастерству**
# * $ P(L) = 0.45 $ - обучение **иностранному языку**
# * $ P(S|P) = 0.8 $ - сотрудники с **программирования**, которые **успешно** сдали экзамен
# * $ P(S|O) = 0.75 $ - сотрудники с **ораторского мастерства**, которые **успешно** сдали экзамен
# * $ P(S|L) = 0.6 $ - сотрудники с **иностранного языка**, которые **успешно** сдали экзамен
#
# 1. Найдите вероятность того, что случайно выбранный сотрудник успешно сдаст экзамен по курсу.
#
#     $ P(S) = P(S|P) \cdot P(P) + P(S|O) \cdot P(O) + P(S|L) \cdot P(L) \approx 0.69 $
# 2. Найдите вероятность того, что сотрудник посещал именно курсы по ораторскому мастерству, если известно, что экзамен не был сдан.
#
#     $ P(\overline{S}) = 1 - P(S) = 0.3075 $
#     $ P(\overline{S}|O) = 1 - P(S|O) = 0.25 $
#     $ P(O|\overline{S}) = \frac{P(\overline{S}|O) \times P(O)}{P(\overline{S})} = \frac{0.25 \times 0.35}{0.3075} \approx 0.28 $

# %% [markdown]
# # <center> Случайная величина и её характеристики
#
# **Задание 7.3**
# Вы с другом играете в игру, подбрасывая две идеальные (не «шулерские») монетки. Если выпало две решки, вы проиграли и платите противнику 100 рублей. Если выпало два орла, вы выиграли и противник платит вам 100 рублей. Если выпали один орёл и одна решка, объявляется ничья и вы оба платите по 50 рублей ведущему.
#
# |X|-100|-50|100|
# |-|-|-|-|
# |P|0.25|0.5|0.25|
# 1. Посчитайте ваш ожидаемый выигрыш в рублях:
#
#     $ E(X) = \sum^3_{i=1} x_i \cdot P(X=x_i) = -100 \cdot 0.25 + -50 \cdot 0.5 + 100 \cdot 0.25 = -25 $
#
# |X|0|100|0|
# |-|-|-|-|
# |P|0.25|0.5|0.25|
#
# 2. Посчитайте ожидаемый выигрыш ведущего в рублях:
#
#     $ E(X) = \sum^3_{i=1} x_i \cdot P(X=x_i) = 100 \cdot 0.5 = 50 $
#
# **Задание 7.4**
# Случайная величина задана таблицей:
#
# |X|-1|0|1|2|
# |-|-|-|-|-|
# |P|0.5|0.2|0.2|0.1|
#
# Найдите следующие значения:
#
# 1. $ E(X) = \sum^4_{i=1} x_i \cdot P(X=x_i) = -0.1 $
# 2. $ E(X^2) = (-1)^2 \cdot 0.5 + 1^2 \cdot 0.2 + 2^2 \cdot 0.1 = 1.1 $
#
# **Задание 7.7**
# Случайная величина задана таблицей:
#
# |X|-1|0|1|2|
# |-|-|-|-|-|
# |P|0.5|0.2|0.2|0.1|
#
# Найдите стандартное отклонение $X$.
#
# $$ E(X) = -0.1 $$
# $$ E(X^2) = 1.1 $$
# $$ V(X) = E(X^2) - (E(X))^2 = 1.09 $$
# $$ \sigma = \sqrt{V(X)} = 1.04 $$

# %% [markdown]
# # <center>Дискретные распределения
# ## <center>Непрерывное распределение

# %%
import numpy as np
from scipy.stats import randint

# %% [markdown]
# Попробуем рассчитать вероятности для случайной величины, которая принимает значения от 1 включительно до 7 не включительно (собственно, это как раз пример с пирожными):

# %%
# Задаём возможные значения случайной величины
x = np.arange(1, 7)
# Задаём интервал, на котором будут распределяться наши вероятности
disc_uni_dist = randint(1, 7)
# Вычисляем вероятности выпадения каждого значения случайной величины
pmf = disc_uni_dist.pmf(x)

# %% [markdown]
# Получаем вероятности для каждого из шести значений:

# %%
pmf
# Out:
# array([0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667])

# %% [markdown]
# Также мы можем найти кумулятивную вероятность для распределения, то есть для каждого $x_i$ вероятность того, что случайная величина примет значение $x_i$ или меньше:

# %%
# Рассчитаем кумулятивную вероятность
cdf = disc_uni_dist.cdf(x)
print(cdf)
# Out:
# [0.16666667 0.33333333 0.5        0.66666667 0.83333333 1.        ]

# %% [markdown]
# ***
# **Пример**
# Вы участвуете в розыгрыше бесплатного места на новый курс по Data Science. Вы знаете, что участников 250.
#
# Какова вероятность, что на курс попадёт кто-то из первых пятидесяти зарегистрировавшихся?

# %%
# Задаём возможные значения случайной величины
x = np.arange(1, 251)
# Задаём интервал, на котором будут распределяться наши вероятности
disc_uni_dist = randint(1,251)
# Вычисляем вероятности выпадения каждого значения случайной величины
cdf = disc_uni_dist.cdf(x)
# Ищем вероятность того, что на курс попадёт кто-то из первых 50 зарегистрировавшихся
print(cdf[49])
# Out:
# 0.2

# %% [markdown]
# В результате получаем $0.2$ — это вероятность того, что выигрыш получит кто-то, чей порядковый номер — от 1 до 50. Разумеется, вероятность не зависит от самого номера, поэтому для номеров с 51 по 100 вероятность будет ровно такая же.

# %% [markdown]
# ***
# ## <center>Распределение Бернулли
# С помощью специальной функции `bernoulli.rvs()` из библиотеки `scipy` мы можем смоделировать распределение Бернулли и, например, увидеть ожидаемое соотношение попаданий и промахов для решённой задачи, если будет сделано 500 выстрелов:

# %%
from scipy.stats import bernoulli
import seaborn as sns

data = bernoulli.rvs(size=500, p=0.6)
ax = sns.displot(
    data,
    color='dodgerblue',
)
ax.set(xlabel='Значение случайной величины', ylabel='Частота');

# %% [markdown]
# Также можно вывести количество неудач и попаданий в нашей модели:

# %%
unique, counts = np.unique(data, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  0 212]
#  [  1 288]]

# %% [markdown]
# ***
# ## <center>Биномиальное распределение
# **Пример**
# Производитель гаджетов знает, что 20 % производимых им товаров — бракованные.
#
# Если он производит десять изделий в день, какова вероятность того, что не более двух из них бракованные?
# ![image.png](attachment:image.png)

# %%
import scipy

scipy.stats.binom.pmf(8,10,0.8) + scipy.stats.binom.pmf(9,10,0.8) + scipy.stats.binom.pmf(10,10,0.8)
# Out:
# 0.6777995264

# %% [markdown]
# Как и для распределения Бернулли, для биномиального распределения можно смоделировать какое-то количество попыток и получить результат. Например, можно смоделировать биноминальное распределение с параметром p = 0.5 и количеством испытаний, равным 10, и реализовать 1000 попыток:

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

x = random.binomial(n=10, p=0.5, size=1000)

sns.displot(x)

plt.show()

# %% [markdown]
# Можно видеть, что чаще всего можно наблюдать пять успешных исходов.

# %% [markdown]
# ## <center>Распределение Пуассона

# %% [markdown]
# **Пример**
# Колл-центр получает в среднем 4.5 звонка за каждые пять минут. Каждый оператор может обработать один из этих вызовов в течение пяти минут. Если вызов получен, но оператор  не может его принять, то вызывающий абонент будет переведён в режим ожидания ответа.
#
# Если вызовы следуют распределению Пуассона, какое минимальное количество операторов необходимо колл-центру, чтобы вероятность попадания вызова на удержание была не более 0.1?
#
# Рассчитаем вероятности для всех возможных количеств операторов, пока не получим вероятность того, что вызов находится на удержании, которая будет меньше 10 %:
#
# ![image.png](attachment:image.png)
#
# В качестве параметра $\lambda$ мы берём среднее количество звонков, так как это наше ожидаемое число событий, а в качестве $k$ — количество операторов, т. к. в данный период времени мы сможем принять столько звонков (один оператор принимает один звонок).
#
# Получаем, что колл-центру необходимо нанять на работу хотя бы семь операторов.
#
# Разумеется, все эти значения можно было бы рассчитать намного проще с использованием функций `Python`. Например, для пяти операторов мы бы получили следующее выражение:

# %%
import scipy

scipy.stats.distributions.poisson.pmf(5, 4.5)
# Out:
# 0.17082685848611215

# %% [markdown]
# Также можно смоделировать распределение Пуассона. Например, будем рассматривать 1000 реализаций случайной величины, у которой $\lambda = 3$:

# %%
from numpy import random

sns.displot(random.poisson(lam=3, size=1000), kde=False)

plt.show()

# %% [markdown]
# **Задание 8.6**
# Сеть ресторанов быстрого питания проводит акцию, в рамках которой в одной из четырёх коробок картофеля фри лежит купон на бесплатную коробку картофеля фри. Предположим, что где-то продаётся 100 таких коробок в день. Пусть $X$ равно количеству выигранных купонов за день.
#
# Найдите среднее значение и стандартное отклонение для $X$. Если результат дробное число, округлите ответ до одного знака после точки-разделителя.
#
# |X|0|1|
# |-|-|-|
# |P|0.75|0.25|
#
# $ E(X) = 0.25 $
# $ E(X^2) = 0.25 $
# $ E(100 X) = 25 $
# $ V(X) = E(X^2) - (E(X))^2 = 0.25 - 0.0625 = 0.1875 $
# $ V(100X) = 18.75 $
# $ \sigma_X = \sqrt{V(X)} = \sqrt{0.1875} \approx 0.433 $
# $ \sigma_{100X} = \sqrt{V(100X)} = \sqrt{18.75} \approx 4.3 $
# ***
# **Задание 8.7**
# Пассажиры прибывают на вокзал со средней скоростью $\lambda=4$ человека в минуту.
#
# Если количество пассажиров, приезжающих на вокзал, подчиняется распределению Пуассона, какова приблизительная вероятность того, что 16 пассажиров приедут на вокзал в конкретный четырёхминутный период?

# %%
scipy.stats.distributions.poisson.pmf(16, 4*4)
# Out:
# 0.09921753162215541

# %% [markdown]
# ## <center>Равномерное распределение
# Мы можем с помощью Python смоделировать случайную величину c таким распределением и визуализировать плотность её распределения. К примеру, сформируем выборку объёмом 10000 для распределения с параметрами $a=10$ и $b=40$:

# %%
data = random.uniform(size=10000, low=10, high=40)
ax = sns.displot(data, bins=50, kde=True)
ax.set(xlabel='Равномерное распределение', ylabel='Плотность');

# %% [markdown]
# ## <center>Нормальное распределение

# %% [markdown]
# Cмоделируем нормальное распределение с математическим ожиданием, равным $5$, и стандартным отклонением, равным $4$, и посмотрим, какой вид оно примет.

# %%
from scipy.stats import norm

data = norm.rvs(size=10000, loc=4, scale=5)
 
ax = sns.displot(data, bins=50, kde=True)
ax.set(xlabel='Нормальное распределение', ylabel='Плотность');

# %% [markdown]
# **Стандартизация**

# %%
from sklearn.preprocessing import StandardScaler
data = np.array([
    [93, 44],
    [4, 2],
    [36, 1],
    [14, 29],
    [78, 21]
])
scaler = StandardScaler()
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[ 1.37243726  1.50201177]
#  [-1.17229016 -1.06239857]
#  [-0.25733199 -1.12345596]
#  [-0.88636573  0.58615094]
#  [ 0.94355062  0.09769182]]

# %% [markdown]
# ## <center>Экспоненциальное распределение

# %%
from scipy.stats import expon
data = expon.rvs(scale=1, loc=0, size=1000)
ax = sns.displot(data, bins=50, kde=True)
ax.set(xlabel='Экспоненциальное распределение', ylabel='Плотность');

# %% [markdown]
# **Задание 9.4**
# В среднем новый холодильник служит 10 лет. Предположим, что продолжительность времени службы распределена экспоненциально.
#
# $ \lambda = \frac{1}{10} $
#
# 1. Какова вероятность того, что холодильник прослужит более 7 лет?
#
#     $ P(X>7) = e^{-\lambda 7} = e^{-0.7} \approx 0.497 $
#
# 2. Какова вероятность того, что устройство прослужит от 9 до 11 лет?
#
#     $ P(9<X<11) = P(X<11) - P(X<9) = (1 - e^{-(0.1 \cdot 11)}) - (1 - e^{-(0.1 \cdot 0.9)}) = e^{-(0.1 \cdot 0.9)} - e^{-(0.1 \cdot 11)} \approx 0.0737 $

# %% [markdown]
# **Задание 10.1**
# В вашем офисе стоят два автомата, с кофе и с чаем. Вероятность того, что к концу дня ваши коллеги выпьют весь кофе, равна $0.2$. Для чая соответствующая вероятность равна $0.3$.
#
# Найдите вероятность того, что хотя бы в одном из автоматов закончится напиток.
#
# Считайте, что напитки заканчиваются независимо друг от друга.
